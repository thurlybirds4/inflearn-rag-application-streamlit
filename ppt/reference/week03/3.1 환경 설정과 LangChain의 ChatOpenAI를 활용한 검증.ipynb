# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -r requirements.txt
# %pip install "langchain-google-genai>=2.0.0"
# Out:
# I0828 18:15:23.839662 1241087 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# Requirement already satisfied: aiohappyeyeballs==2.4.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.4.3)
# Requirement already satisfied: aiohttp==3.9.5 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.9.5)
# Requirement already satisfied: aiosignal==1.3.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: annotated-types==0.7.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: anyio==4.6.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (4.6.2)
# Requirement already satisfied: appnope==0.1.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: asgiref==3.8.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.8.1)
# Requirement already satisfied: asttokens==2.4.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: async-timeout==4.0.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (4.0.3)
# Requirement already satisfied: attrs==24.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (24.2.0)
# Requirement already satisfied: backoff==2.2.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: bcrypt==4.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (4.2.0)
# Requirement already satisfied: build==1.2.2.post1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.2.2.post1)
# Requirement already satisfied: cachetools==5.5.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: certifi==2024.8.30 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2024.8.30)
# Requirement already satisfied: charset-normalizer==3.4.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (3.4.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (0.7.6)
# Requirement already satisfied: chromadb==0.5.13 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (0.5.13)
# Requirement already satisfied: click==8.1.7 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (8.1.7)
# Requirement already satisfied: coloredlogs==15.0.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (15.0.1)
# Requirement already satisfied: comm==0.2.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (0.2.2)
# Requirement already satisfied: dataclasses-json==0.6.7 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.6.7)
# Requirement already satisfied: debugpy==1.8.7 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (1.8.7)
# Requirement already satisfied: decorator==5.1.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (5.1.1)
# Requirement already satisfied: Deprecated==1.2.14 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.2.14)
# Requirement already satisfied: distro==1.9.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (1.9.0)
# Requirement already satisfied: docx2txt==0.8 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (0.8)
# Requirement already satisfied: durationpy==0.9 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.9)
# Requirement already satisfied: exceptiongroup==1.2.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (1.2.2)
# Requirement already satisfied: executing==2.1.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (2.1.0)
# Requirement already satisfied: fastapi==0.115.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (0.115.2)
# Requirement already satisfied: filelock==3.16.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (3.16.1)
# Requirement already satisfied: flatbuffers==24.3.25 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (24.3.25)
# Requirement already satisfied: frozenlist==1.4.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (1.4.1)
# Requirement already satisfied: fsspec==2024.9.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (2024.9.0)
# Requirement already satisfied: google-auth==2.35.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (2.35.0)
# Requirement already satisfied: googleapis-common-protos==1.65.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (1.65.0)
# Requirement already satisfied: grpcio==1.66.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (1.66.2)
# Requirement already satisfied: h11==0.14.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.6 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (1.0.6)
# Requirement already satisfied: httptools==0.6.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (0.6.2)
# Requirement already satisfied: httpx==0.27.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (0.27.2)
# Requirement already satisfied: huggingface-hub==0.25.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (0.25.2)
# Requirement already satisfied: humanfriendly==10.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (10.0)
# Requirement already satisfied: idna==3.10 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (3.10)
# Requirement already satisfied: importlib_metadata==8.4.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (8.4.0)
# Requirement already satisfied: importlib_resources==6.4.5 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (6.4.5)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (6.29.5)
# Requirement already satisfied: ipython==8.28.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (8.28.0)
# Requirement already satisfied: jedi==0.19.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (0.19.1)
# Requirement already satisfied: jiter==0.6.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 51)) (0.6.1)
# Requirement already satisfied: jsonpatch==1.33 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 53)) (3.0.0)
# Requirement already satisfied: jupyter_client==8.6.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (5.7.2)
# Requirement already satisfied: kubernetes==31.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (31.0.0)
# Requirement already satisfied: langchain==0.3.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (0.3.3)
# Requirement already satisfied: langchain-chroma==0.1.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 58)) (0.1.4)
# Requirement already satisfied: langchain-community==0.3.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (0.3.2)
# Requirement already satisfied: langchain-core==0.3.10 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 60)) (0.3.10)
# Requirement already satisfied: langchain-openai==0.2.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (0.2.2)
# Requirement already satisfied: langchain-pinecone==0.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 62)) (0.2.0)
# Requirement already satisfied: langchain-text-splitters==0.3.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (0.3.0)
# Requirement already satisfied: langchain-upstage==0.3.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 64)) (0.3.0)
# Requirement already satisfied: langsmith==0.1.134 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 65)) (0.1.134)
# Requirement already satisfied: lxml==5.3.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 66)) (5.3.0)
# Requirement already satisfied: markdown-it-py==3.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 67)) (3.0.0)
# Requirement already satisfied: marshmallow==3.22.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 68)) (3.22.0)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 69)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 70)) (0.1.2)
# Requirement already satisfied: mmh3==5.0.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 71)) (5.0.1)
# Requirement already satisfied: monotonic==1.6 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 72)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 73)) (1.3.0)
# Requirement already satisfied: multidict==6.1.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 74)) (6.1.0)
# Requirement already satisfied: mypy-extensions==1.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 75)) (1.0.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 76)) (1.6.0)
# Requirement already satisfied: numpy==1.26.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 77)) (1.26.4)
# Requirement already satisfied: oauthlib==3.2.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 78)) (3.2.2)
# Requirement already satisfied: onnxruntime==1.19.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 79)) (1.19.2)
# Requirement already satisfied: openai==1.51.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 80)) (1.51.2)
# Requirement already satisfied: opentelemetry-api==1.27.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 81)) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 82)) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 83)) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 84)) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 85)) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi==0.48b0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 86)) (0.48b0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 87)) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk==1.27.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 88)) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 89)) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 90)) (0.48b0)
# Requirement already satisfied: orjson==3.10.7 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 91)) (3.10.7)
# Requirement already satisfied: overrides==7.7.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 92)) (7.7.0)
# Requirement already satisfied: packaging==24.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 93)) (24.1)
# Requirement already satisfied: parso==0.8.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 94)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 95)) (4.9.0)
# Requirement already satisfied: pinecone-client==5.0.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 96)) (5.0.1)
# Requirement already satisfied: pinecone-plugin-inference==1.1.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 97)) (1.1.0)
# Requirement already satisfied: pinecone-plugin-interface==0.0.7 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 98)) (0.0.7)
# Requirement already satisfied: platformdirs==4.3.6 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 99)) (4.3.6)
# Requirement already satisfied: posthog==3.7.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 100)) (3.7.0)
# Requirement already satisfied: prompt_toolkit==3.0.48 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 101)) (3.0.48)
# Requirement already satisfied: propcache==0.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 102)) (0.2.0)
# Collecting protobuf==4.25.5
#   Using cached protobuf-4.25.5-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Requirement already satisfied: psutil==6.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 104)) (6.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 105)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 106)) (0.2.3)
# Requirement already satisfied: pyasn1==0.6.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 107)) (0.6.1)
# Requirement already satisfied: pyasn1_modules==0.4.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 108)) (0.4.1)
# Requirement already satisfied: pydantic==2.9.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 109)) (2.9.2)
# Requirement already satisfied: pydantic-settings==2.5.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 110)) (2.5.2)
# Requirement already satisfied: pydantic_core==2.23.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 111)) (2.23.4)
# Requirement already satisfied: Pygments==2.18.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 112)) (2.18.0)
# Requirement already satisfied: pypdf==4.3.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 113)) (4.3.1)
# Requirement already satisfied: PyPika==0.48.9 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 114)) (0.48.9)
# Requirement already satisfied: pyproject_hooks==1.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 115)) (1.2.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 116)) (2.9.0.post0)
# Requirement already satisfied: python-docx==1.1.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 117)) (1.1.2)
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 118)) (1.0.1)
# Requirement already satisfied: PyYAML==6.0.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 119)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 120)) (26.2.0)
# Requirement already satisfied: regex==2024.9.11 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 121)) (2024.9.11)
# Requirement already satisfied: requests==2.32.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 122)) (2.32.3)
# Requirement already satisfied: requests-oauthlib==2.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 123)) (2.0.0)
# Requirement already satisfied: requests-toolbelt==1.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 124)) (1.0.0)
# Requirement already satisfied: rich==13.9.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 125)) (13.9.2)
# Requirement already satisfied: rsa==4.9 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 126)) (4.9)
# Requirement already satisfied: shellingham==1.5.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 127)) (1.5.4)
# Requirement already satisfied: six==1.16.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 128)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 129)) (1.3.1)
# Requirement already satisfied: SQLAlchemy==2.0.35 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 130)) (2.0.35)
# Requirement already satisfied: stack-data==0.6.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 131)) (0.6.3)
# Requirement already satisfied: starlette==0.40.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 132)) (0.40.0)
# Requirement already satisfied: sympy==1.13.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 133)) (1.13.3)
# Requirement already satisfied: tenacity==8.5.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 134)) (8.5.0)
# Requirement already satisfied: tiktoken==0.8.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 135)) (0.8.0)
# Requirement already satisfied: tokenizers==0.19.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 136)) (0.19.1)
# Requirement already satisfied: tomli==2.0.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 137)) (2.0.2)
# Requirement already satisfied: tornado==6.4.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 138)) (6.4.1)
# Requirement already satisfied: tqdm==4.66.5 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 139)) (4.66.5)
# Requirement already satisfied: traitlets==5.14.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 140)) (5.14.3)
# Requirement already satisfied: typer==0.12.5 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 141)) (0.12.5)
# Requirement already satisfied: typing-inspect==0.9.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 142)) (0.9.0)
# Requirement already satisfied: typing_extensions==4.12.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 143)) (4.12.2)
# Requirement already satisfied: urllib3==2.2.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 144)) (2.2.3)
# Requirement already satisfied: uvicorn==0.31.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 145)) (0.31.1)
# Requirement already satisfied: uvloop==0.21.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 146)) (0.21.0)
# Requirement already satisfied: watchfiles==0.24.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 147)) (0.24.0)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 148)) (0.2.13)
# Requirement already satisfied: websocket-client==1.8.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 149)) (1.8.0)
# Requirement already satisfied: websockets==13.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 150)) (13.1)
# Requirement already satisfied: wrapt==1.16.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 151)) (1.16.0)
# Requirement already satisfied: yarl==1.15.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 152)) (1.15.2)
# Requirement already satisfied: zipp==3.20.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from -r requirements.txt (line 153)) (3.20.2)
# Requirement already satisfied: setuptools>=16.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.48b0->-r requirements.txt (line 84)) (65.5.0)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# proto-plus 1.28.2 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 4.25.5 which is incompatible.
# google-api-core 2.30.3 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 4.25.5 which is incompatible.
# Successfully installed protobuf-4.25.5
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# I0828 18:15:25.629859 1241087 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# Requirement already satisfied: langchain-google-genai>=2.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-google-genai>=2.0.0) (0.8.6)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-google-genai>=2.0.0) (0.3.10)
# Requirement already satisfied: pydantic<3,>=2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-google-genai>=2.0.0) (2.9.2)
# Requirement already satisfied: google-api-python-client in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (2.199.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (0.6.15)
# Requirement already satisfied: typing-extensions in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (4.12.2)
# Requirement already satisfied: protobuf in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (4.25.5)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (2.35.0)
# Requirement already satisfied: google-api-core in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (2.30.3)
# Requirement already satisfied: tqdm in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (4.66.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (1.28.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (8.5.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (0.1.134)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (24.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (6.0.2)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from pydantic<3,>=2->langchain-google-genai>=2.0.0) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from pydantic<3,>=2->langchain-google-genai>=2.0.0) (0.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (5.5.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (0.27.2)
# Requirement already satisfied: requests<3,>=2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (3.10.7)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (1.65.0)
# Collecting protobuf
#   Using cached protobuf-5.29.6-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (0.32.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (4.2.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (1.66.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (1.62.3)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (3.3.2)
# Requirement already satisfied: sniffio in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (1.3.1)
# Requirement already satisfied: anyio in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (4.6.2)
# Requirement already satisfied: certifi in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (2024.8.30)
# Requirement already satisfied: idna in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai>=2.0.0) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (2.2.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jeong-yujin/.pyenv/versions/3.10.18/envs/inflearn-llm-application-ver2/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai>=2.0.0) (1.2.2)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.27.0 requires protobuf<5.0,>=3.19, but you have protobuf 5.29.6 which is incompatible.
# Successfully installed protobuf-5.29.6
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv
from pathlib import Path
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - OpenAI 대시보드에서 발급받은 API Key를 `OPENAI_API_KEY`라고 저장하면 별도의 설정 없이 `ChatOpenAI`를 사용할 수 있음

# %%
# from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

# llm = ChatOpenAI(model_name='gpt-4o-mini')
llm = ChatGoogleGenerativeAI(model='gemini-3.6-flash')

# %%
import time
start = time.time()

try:
    ai_message = llm.invoke("상명대는 어떤 대학교 인가요?")
    print(ai_message.content)
except Exception as e:
    print(e.message)
    
print(time.time() - start)
# Out:
# **상명대학교(Sangmyung University)**는 서울특별시 종로구와 충청남도 천안시에 캠퍼스를 두고 있는 **4년제 종합 사립대학교**입니다.
#
# 상명대학교의 주요 특징과 장점, 캠퍼스별 특성 등을 정리해 드리겠습니다.
#
# ---
#
# ### 1. 캠퍼스 이원화 운영
# 상명대학교는 서울과 천안 두 곳에 캠퍼스를 두고 있으며, 각 캠퍼스별로 특화된 학과들을 운영하고 있습니다.
#
# *   **서울캠퍼스 (서울특별시 종로구 홍지동)**
#     *   **주요 학문:** 인문, 사회, 사범, 자연과학, SW융합, 경영 등
#     *   **특징:** 서울 중심부(경복궁, 광화문 인근)와 가까운 종로구에 위치해 있습니다. 특히 **사범대학**이 전통적으로 강세를 보이며, 최근에는 **AI·SW 관련 융합 전공**에 많은 투자를 하고 있습니다.
# *   **천안캠퍼스 (충청남도 천안시 동남구 안서동)**
#     *   **주요 학문:** 디자인, 예술, 융합기술, 글로벌인문학 등
#     *   **특징:** **디자인 및 예술 분야**가 매우 유명합니다. 텍스타일디자인, 스페이스디자인, 영화영상, 연극, 사진 등 예체능 계열의 인지도와 경쟁력이 전국적으로 높습니다.
#
# ---
#
# ### 2. 상명대학교의 주요 강점 및 특징
#
# *   **디자인·예술 계열의 높은 인지도**
#     *   상명대는 전통적으로 **디자인, 미술, 체육, 공연예술(연극, 영화 등)** 분야에서 뛰어난 성과를 내왔습니다. 관련 업계에 수많은 졸업생들이 진출해 있습니다.
# *   **사범대학 보유 (교원 양성)**
#     *   서울 소재 사립대 중 사범대학을 갖춘 몇 안 되는 대학 중 하나입니다. 국어·영어·수학·일어·불어·독도·교육학 등 다양한 사범계열 학과가 있어 임용고시 준비생들에게 인기가 높습니다.
# *   **SW(소프트웨어) 중심대학 및 신산업 분야 투자**
#     *   정부의 'SW중심대학' 사업 등에 선정되어, 문과/이과 구분 없이 전 학생을 대상으로 AI 및 소프트웨어 기초 교육을 실시하고 있으며, 관련 융합 전공을 적극 권장하고 있습니다.
# *   **여대에서 남녀공학으로의 성공적 전환**
#     *   1937년 '상명고등기능학교'로 시작하여 '상명여자대학교'로 성장했다가, **1996년에 남녀공학으로 전환**되었습니다. 이후 종합대학으로서의 입지를 더욱 탄탄히 다졌습니다.
#
# ---
#
# ### 3. 캠퍼스 환경 및 특징
#
# *   **서울캠퍼스:** 북악산과 인왕산 자락에 위치해 있어 공기가 좋고 자연경관이 뛰어납니다. 다만, 경사가 다소 급한 편이라 학생들 사이에서 '언덕'으로 유명하며, 서울 중심가와 가까워 문화생활이나 외부 활동을 하기에 좋습니다.
# *   **천안캠퍼스:** 여러 대학교가 모여 있는 천안 안서동 대학가에 위치해 있으며, 서울캠퍼스에 비해 평지 비율이 높고 전형적인 대학 캠퍼스의 낭만을 느낄 수 있는 환경입니다.
#
# ---
#
# ### 요약
# 상명대학교는 **'인서울 종합대학'**으로서의 입지, **'디자인 및 예술 분야'의 강세**, 그리고 **'사범대학 및 SW융합교육'**이라는 명확한 강점을 가진 대학입니다. 학과에 따라 서울과 천안으로 나누어져 있으므로, 진학이나 정보 탐색 시 본인이 희망하는 전공이 어느 캠퍼스에 있는지 확인하는 것이 좋습니다.
# 17.425285816192627
